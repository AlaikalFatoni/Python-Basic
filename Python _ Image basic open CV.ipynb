# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
data = cv2.imread("gambar12.png")
data
# Out:
# array([[[251, 214, 192],
#         [251, 214, 192],
#         [251, 214, 192],
#         ...,
#         [248, 213, 199],
#         [248, 213, 199],
#         [249, 214, 200]],
#
#        [[251, 214, 192],
#         [251, 214, 192],
#         [251, 214, 192],
#         ...,
#         [246, 213, 198],
#         [246, 213, 198],
#         [246, 213, 198]],
#
#        [[251, 214, 192],
#         [251, 214, 192],
#         [251, 214, 192],
#         ...,
#         [246, 213, 198],
#         [246, 213, 198],
#         [246, 213, 198]],
#
#        ...,
#
#        [[ 24,  20,  17],
#         [ 25,  20,  18],
#         [ 24,  20,  17],
#         ...,
#         [ 26,  20,  17],
#         [ 25,  20,  16],
#         [ 26,  20,  16]],
#
#        [[ 24,  19,  17],
#         [ 24,  20,  17],
#         [ 23,  19,  16],
#         ...,
#         [ 26,  21,  17],
#         [ 26,  20,  16],
#         [ 26,  20,  16]],
#
#        [[ 25,  21,  18],
#         [ 24,  20,  17],
#         [ 24,  19,  17],
# ...

# %%
data.shape
# Out:
# (1166, 656, 3)

# %%
plt.imshow(data)

# %%
data_rgb = cv2.cvtColor(data, cv2.COLOR_BGR2RGB)
plt.imshow(data_rgb)
plt.show()

# %%
data_grey = cv2.imread('wa.jpeg', cv2.IMREAD_GRAYSCALE)
plt.imshow(data_grey, cmap='gray')
plt.show()

# %%
data_grey
# Out:
# array([[185, 180, 174, ..., 163, 168, 168],
#        [186, 181, 177, ..., 161, 165, 166],
#        [185, 182, 180, ..., 162, 162, 166],
#        ...,
#        [220, 219, 217, ...,  34,  28,  25],
#        [220, 219, 216, ...,  40,  39,  39],
#        [223, 222, 219, ...,  35,  36,  38]], dtype=uint8)

# %%
data_size=cv2.resize(data, (1080, 1350))
plt.imshow(data_size)
plt.show()

# %%
w_ratio = 0.5
h_ratio = 0.5
foto01 = cv2.resize(data, (0,0), data, w_ratio, h_ratio)
plt.imshow(foto01)

# %%
data_flip=cv2.flip(data_size, 1)
plt.imshow(data_flip)

# %%
type(data_size)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('doc23.jpg', data_size)
# Out:
# True
